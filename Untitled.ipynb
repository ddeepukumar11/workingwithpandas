# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import datetime as dt

# %%
df = pd.read_csv('data.csv')
# Out:
# c:\users\puni\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1 = df[df.location=='Argentina-Catamarca']

# %%
df1
# Out:
#      report_date             location location_type  \
# 12    2016-03-19  Argentina-Catamarca      province
# 13    2016-03-19  Argentina-Catamarca      province
# 14    2016-03-19  Argentina-Catamarca      province
# 15    2016-03-19  Argentina-Catamarca      province
# 16    2016-03-19  Argentina-Catamarca      province
# 17    2016-03-19  Argentina-Catamarca      province
# 156   2016-03-26  Argentina-Catamarca      province
# 157   2016-03-26  Argentina-Catamarca      province
# 158   2016-03-26  Argentina-Catamarca      province
# 159   2016-03-26  Argentina-Catamarca      province
# 160   2016-03-26  Argentina-Catamarca      province
# 161   2016-03-26  Argentina-Catamarca      province
# 300   2016-04-02  Argentina-Catamarca      province
# 301   2016-04-02  Argentina-Catamarca      province
# 302   2016-04-02  Argentina-Catamarca      province
# 303   2016-04-02  Argentina-Catamarca      province
# 304   2016-04-02  Argentina-Catamarca      province
# ...

# %%
#show data field code 'AR0005' values for 'Argentina-Catamarca' for entire duration

# %%
df1[df1.data_field_code=='AR0005']
# Out:
#      report_date             location location_type  \
# 16    2016-03-19  Argentina-Catamarca      province
# 160   2016-03-26  Argentina-Catamarca      province
# 304   2016-04-02  Argentina-Catamarca      province
# 448   2016-04-09  Argentina-Catamarca      province
# 592   2016-04-16  Argentina-Catamarca      province
# 736   2016-04-29  Argentina-Catamarca      province
# 880   2016-05-07  Argentina-Catamarca      province
# 1024  2016-05-14  Argentina-Catamarca      province
# 1168  2016-05-22  Argentina-Catamarca      province
# 1312  2016-05-30  Argentina-Catamarca      province
# 1456  2016-06-06  Argentina-Catamarca      province
# 1600  2016-06-13  Argentina-Catamarca      province
# 1744  2016-06-18  Argentina-Catamarca      province
# 1888  2016-06-26  Argentina-Catamarca      province
#
#                         data_field data_field_code  time_period  \
# 16    cumulative_cases_under_study          AR0005          NaN
# ...

# %%
df.head()
# Out:
#   report_date                location location_type  \
# 0  2016-03-19  Argentina-Buenos_Aires      province
# 1  2016-03-19  Argentina-Buenos_Aires      province
# 2  2016-03-19  Argentina-Buenos_Aires      province
# 3  2016-03-19  Argentina-Buenos_Aires      province
# 4  2016-03-19  Argentina-Buenos_Aires      province
#
#                             data_field data_field_code  time_period  \
# 0     cumulative_confirmed_local_cases          AR0001          NaN
# 1      cumulative_probable_local_cases          AR0002          NaN
# 2  cumulative_confirmed_imported_cases          AR0003          NaN
# 3   cumulative_probable_imported_cases          AR0004          NaN
# 4         cumulative_cases_under_study          AR0005          NaN
#
#    time_period_type value   unit
# 0               NaN     0  cases
# 1               NaN     0  cases
# 2               NaN     2  cases
# 3               NaN     1  cases
# 4               NaN   127  cases

# %%
df1 = df[df.unit=='cases']

# %%
df1
# Out:
#        report_date                                   location location_type  \
# 0       2016-03-19                     Argentina-Buenos_Aires      province
# 1       2016-03-19                     Argentina-Buenos_Aires      province
# 2       2016-03-19                     Argentina-Buenos_Aires      province
# 3       2016-03-19                     Argentina-Buenos_Aires      province
# 4       2016-03-19                     Argentina-Buenos_Aires      province
# 5       2016-03-19                     Argentina-Buenos_Aires      province
# 6       2016-03-19                             Argentina-CABA      province
# 7       2016-03-19                             Argentina-CABA      province
# 8       2016-03-19                             Argentina-CABA      province
# 9       2016-03-19                             Argentina-CABA      province
# 10      2016-03-19                             Argentina-CABA      province
# ...

# %%
df1 = df1.loc[df1['location'].isin(['Argentina-CABA','Argentina-Catamarca'])]

# %%
df1
# Out:
#      report_date             location location_type  \
# 6     2016-03-19       Argentina-CABA      province
# 7     2016-03-19       Argentina-CABA      province
# 8     2016-03-19       Argentina-CABA      province
# 9     2016-03-19       Argentina-CABA      province
# 10    2016-03-19       Argentina-CABA      province
# 11    2016-03-19       Argentina-CABA      province
# 12    2016-03-19  Argentina-Catamarca      province
# 13    2016-03-19  Argentina-Catamarca      province
# 14    2016-03-19  Argentina-Catamarca      province
# 15    2016-03-19  Argentina-Catamarca      province
# 16    2016-03-19  Argentina-Catamarca      province
# 17    2016-03-19  Argentina-Catamarca      province
# 150   2016-03-26       Argentina-CABA      province
# 151   2016-03-26       Argentina-CABA      province
# 152   2016-03-26       Argentina-CABA      province
# 153   2016-03-26       Argentina-CABA      province
# 154   2016-03-26       Argentina-CABA      province
# ...

# %%
df2 = df1.groupby('location')

# %%
df2

# %%
df3 =df2.get_group('Argentina-CABA')

# %%
df3
# Out:
#      report_date        location location_type  \
# 6     2016-03-19  Argentina-CABA      province
# 7     2016-03-19  Argentina-CABA      province
# 8     2016-03-19  Argentina-CABA      province
# 9     2016-03-19  Argentina-CABA      province
# 10    2016-03-19  Argentina-CABA      province
# 11    2016-03-19  Argentina-CABA      province
# 150   2016-03-26  Argentina-CABA      province
# 151   2016-03-26  Argentina-CABA      province
# 152   2016-03-26  Argentina-CABA      province
# 153   2016-03-26  Argentina-CABA      province
# 154   2016-03-26  Argentina-CABA      province
# 155   2016-03-26  Argentina-CABA      province
# 294   2016-04-02  Argentina-CABA      province
# 295   2016-04-02  Argentina-CABA      province
# 296   2016-04-02  Argentina-CABA      province
# 297   2016-04-02  Argentina-CABA      province
# 298   2016-04-02  Argentina-CABA      province
# 299   2016-04-02  Argentina-CABA      province
# 438   2016-04-09  Argentina-CABA      province
# ...

# %%
dates=pd.unique(df3['report_date'])

# %%
value = df3["value"].tolist()

# %%
value = list(map(int, value))

# %%
sum_values1=np.add.reduceat(value, np.arange(0, len(value), 6))

# %%
dates = pd.to_datetime(dates)

# %%
df5 =df2.get_group('Argentina-Catamarca')

# %%
value1 = df5["value"].tolist()

# %%
value1 = list(map(int, value1))

# %%
sum_values2=np.add.reduceat(value1, np.arange(0, len(value), 6))

# %%
df6 = pd.DataFrame({'Days' : dates,
                    'Argentina_CABA_sum_values' : sum_values1,
                    'Argentina_Catamarca_sum_values' : sum_values2 }, 
                    )

# %%
df6
# Out:
#          Days  Argentina_CABA_sum_values  Argentina_Catamarca_sum_values
# 0  2016-03-19                         78                              14
# 1  2016-03-26                         92                              15
# 2  2016-04-02                         94                              15
# 3  2016-04-09                         97                              15
# 4  2016-04-16                         98                              15
# 5  2016-04-29                        101                              15
# 6  2016-05-07                        255                              16
# 7  2016-05-14                        126                              15
# 8  2016-05-22                        260                              16
# 9  2016-05-30                        132                              15
# 10 2016-06-06                        134                              15
# 11 2016-06-13                        136                              15
# ...

# %%
df6.plot(x="Days", y=["Argentina_CABA_sum_values", "Argentina_Catamarca_sum_values"], kind="bar")

# %%
new_df = df.groupby(by='location')

# %%
#dat field values of Argentina-Buenos_Aires

# %%
new_df.get_group('Argentina-Buenos_Aires').groupby('data_field').size().plot(kind='pie')

# %%
#data field values for Argentina-CABA

# %%
new_df.get_group('Argentina-CABA').groupby('data_field').size().plot(kind='pie')

# %%
#data firld values for Argentina-Catamarca

# %%
new_df.get_group('Argentina-Catamarca').groupby('data_field').size().plot(kind='pie')

# %%
with open("big.txt","r") as f:
    big = f.read().split(" ")

# %%
len(big)
# Out:
# 1036512

# %%
big
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'The',
#  'Adventures',
#  'of',
#  'Sherlock',
#  'Holmes\nby',
#  'Sir',
#  'Arthur',
#  'Conan',
#  'Doyle\n(#15',
#  'in',
#  'our',
#  'series',
#  'by',
#  'Sir',
#  'Arthur',
#  'Conan',
#  'Doyle)\n\nCopyright',
#  'laws',
#  'are',
#  'changing',
#  'all',
#  'over',
#  'the',
#  'world.',
#  'Be',
#  'sure',
#  'to',
#  'check',
#  'the\ncopyright',
#  'laws',
#  'for',
#  'your',
#  'country',
#  'before',
#  'downloading',
#  'or',
#  'redistributing\nthis',
#  'or',
#  'any',
#  'other',
#  'Project',
#  'Gutenberg',
#  'eBook.\n\nThis',
#  'header',
#  'should',
#  'be',
#  'the',
#  'first',
#  'thing',
#  'seen',
#  'when',
#  'viewing',
#  'this',
#  'Project\nGutenberg',
#  'file.',
#  '',
#  'Please',
#  'do',
#  'not',
#  'remove',
#  'it.',
#  '',
#  'Do',
#  'not',
#  'change',
#  'or',
#  'edit',
#  'the\nheader',
#  'without',
#  'written',
#  'permission.\n\nPlease',
#  'read',
#  'the',
# ...

# %%
with open("big.txt","r") as f:
    a = f.read()

# %%
import re

# %%
final = [re.sub(r"[^a-zA-Z0-9]+", ' ', k) for k in a.split(" ")]

# %%
final
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'The',
#  'Adventures',
#  'of',
#  'Sherlock',
#  'Holmes by',
#  'Sir',
#  'Arthur',
#  'Conan',
#  'Doyle 15',
#  'in',
#  'our',
#  'series',
#  'by',
#  'Sir',
#  'Arthur',
#  'Conan',
#  'Doyle Copyright',
#  'laws',
#  'are',
#  'changing',
#  'all',
#  'over',
#  'the',
#  'world ',
#  'Be',
#  'sure',
#  'to',
#  'check',
#  'the copyright',
#  'laws',
#  'for',
#  'your',
#  'country',
#  'before',
#  'downloading',
#  'or',
#  'redistributing this',
#  'or',
#  'any',
#  'other',
#  'Project',
#  'Gutenberg',
#  'eBook This',
#  'header',
#  'should',
#  'be',
#  'the',
#  'first',
#  'thing',
#  'seen',
#  'when',
#  'viewing',
#  'this',
#  'Project Gutenberg',
#  'file ',
#  '',
#  'Please',
#  'do',
#  'not',
#  'remove',
#  'it ',
#  '',
#  'Do',
#  'not',
#  'change',
#  'or',
#  'edit',
#  'the header',
#  'without',
#  'written',
#  'permission Please',
#  'read',
#  'the',
#  ' legal',
#  'small',
# ...

# %%
len(final)
# Out:
# 1036512

# %%
type(final)
# Out:
# list

# %%
fin = pd.unique(final).tolist()

# %%
len(fin)
# Out:
# 124284

# %%
fin
# Out:
# ['The',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'Adventures',
#  'Sherlock',
#  'Holmes by',
#  'Sir',
#  'Arthur',
#  'Conan',
#  'Doyle 15',
#  'in',
#  'our',
#  'series',
#  'by',
#  'Doyle Copyright',
#  'laws',
#  'are',
#  'changing',
#  'all',
#  'over',
#  'the',
#  'world ',
#  'Be',
#  'sure',
#  'to',
#  'check',
#  'the copyright',
#  'for',
#  'your',
#  'country',
#  'before',
#  'downloading',
#  'or',
#  'redistributing this',
#  'any',
#  'other',
#  'eBook This',
#  'header',
#  'should',
#  'be',
#  'first',
#  'thing',
#  'seen',
#  'when',
#  'viewing',
#  'this',
#  'Project Gutenberg',
#  'file ',
#  '',
#  'Please',
#  'do',
#  'not',
#  'remove',
#  'it ',
#  'Do',
#  'change',
#  'edit',
#  'the header',
#  'without',
#  'written',
#  'permission Please',
#  'read',
#  ' legal',
#  'small',
#  'print ',
#  'and',
#  'information',
#  'about',
#  'the eBook',
#  'at',
#  'bottom',
#  'Included',
#  'is important',
#  'specific',
#  'rights',
# ...

# %%
from fuzzywuzzy import process

# %%
def get_matches(query,choices,limit=3):
    results = process.extract(query,choices,limit=limit)
    new_list = [ seq[0] for seq in results ]
    print('the correct word suggestions for wrongly typed word : ')
    print(new_list)

# %%
get_matches("numbr",fin)
# Out:
# the correct word suggestions for wrongly typed word :
# ['number', 'number ', 'NUMBER ']

# %%
get_matches("contry",fin)
# Out:
# the correct word suggestions for wrongly typed word :
# ['country', 'country ', 'COUNTRY']
